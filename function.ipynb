# %%
# Build a function for finding number is prime or not

# %%
n = 1
 
if n%1== 0:
    print("It is prime")
else:
    print("It is not prime")
# Out:
# It is prime

# %%
def primeornot(n):
  if n%1== 0:
    print("It is prime")
  else:
    print("It is not prime")

# %%
primeornot (13)
# Out:
# It is prime

# %%
primeornot (6)
# Out:
# It is prime
